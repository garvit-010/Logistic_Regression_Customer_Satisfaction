# %%
# Importing Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the Data

# %%
data = pd.read_csv("Invistico_Airline.csv")
data.head()
# Out:
#   satisfaction  Gender   Customer Type  Age   Type of Travel     Class  \
# 0    satisfied  Female  Loyal Customer   65  Personal Travel       Eco
# 1    satisfied    Male  Loyal Customer   47  Personal Travel  Business
# 2    satisfied  Female  Loyal Customer   15  Personal Travel       Eco
# 3    satisfied  Female  Loyal Customer   60  Personal Travel       Eco
# 4    satisfied  Female  Loyal Customer   70  Personal Travel       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# ...

# %%
# Explorative Data Analysis

# %%
data.describe()
# Out:
#                  Age  Flight Distance   Seat comfort  \
# count  129880.000000    129880.000000  129880.000000
# mean       39.427957      1981.409055       2.838597
# std        15.119360      1027.115606       1.392983
# min         7.000000        50.000000       0.000000
# 25%        27.000000      1359.000000       2.000000
# 50%        40.000000      1925.000000       3.000000
# 75%        51.000000      2544.000000       4.000000
# max        85.000000      6951.000000       5.000000
#
#        Departure/Arrival time convenient  Food and drink  Gate location  \
# count                      129880.000000   129880.000000  129880.000000
# mean                            2.990645        2.851994       2.990422
# std                             1.527224        1.443729       1.305970
# min                             0.000000        0.000000       0.000000
# 25%                             2.000000        2.000000       2.000000
# ...

# %%
data.columns
# Out:
# Index(['satisfaction', 'Gender', 'Customer Type', 'Age', 'Type of Travel',
#        'Class', 'Flight Distance', 'Seat comfort',
#        'Departure/Arrival time convenient', 'Food and drink', 'Gate location',
#        'Inflight wifi service', 'Inflight entertainment', 'Online support',
#        'Ease of Online booking', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Cleanliness', 'Online boarding',
#        'Departure Delay in Minutes', 'Arrival Delay in Minutes'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
data["satisfaction"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='satisfaction'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  object
#  1   Gender                             129880 non-null  object
#  2   Customer Type                      129880 non-null  object
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  object
#  5   Class                              129880 non-null  object
#  6   Flight Distance                    129880 non-null  int64
#  7   Seat comfort                       129880 non-null  int64
#  8   Departure/Arrival time convenient  129880 non-null  int64
#  9   Food and drink                     129880 non-null  int64
#  10  Gate location                      129880 non-null  int64
# ...

# %%
data.isna().sum()
# Out:
# satisfaction                           0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# ...

# %%
data["Arrival Delay in Minutes"] = data["Arrival Delay in Minutes"].fillna(0)

# %%
data["Arrival Delay in Minutes"].isna().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum()
# Out:
# satisfaction                         0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
# Now Modification of Dtypes to convert into Int or Float

# %%
data.dtypes
# Out:
# satisfaction                          object
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Seat comfort                           int64
# Departure/Arrival time convenient      int64
# Food and drink                         int64
# Gate location                          int64
# Inflight wifi service                  int64
# Inflight entertainment                 int64
# Online support                         int64
# Ease of Online booking                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Cleanliness                            int64
# Online boarding                        int64
# ...

# %%
data.satisfaction.unique(), data["Customer Type"].unique(), data["Type of Travel"].unique()
# Out:
# (array(['satisfied', 'dissatisfied'], dtype=object),
#  array(['Loyal Customer', 'disloyal Customer'], dtype=object),
#  array(['Personal Travel', 'Business travel'], dtype=object))

# %%
data.Class.unique()
# Out:
# array(['Eco', 'Business', 'Eco Plus'], dtype=object)

# %%
# Mapping 0 and 1

# %%
key_1 = {'satisfied': 1, 'dissatisfied': 0}
key_2 = {'Loyal Customer': 1, 'disloyal Customer': 0}
key_3 = {'Personal Travel': 1, 'Business travel': 0}
gender = {"Male": 1, "Female": 0 }

# %%
data["satisfaction"] = data["satisfaction"].map(key_1)
data["Customer Type"] = data["Customer Type"].map(key_2)
data["Type of Travel"] = data["Type of Travel"].map(key_3)
data["Gender"] = data["Gender"].map(gender)

# %%
data.head()
# Out:
#    satisfaction  Gender  Customer Type  Age  Type of Travel     Class  \
# 0             1       0              1   65               1       Eco
# 1             1       1              1   47               1  Business
# 2             1       0              1   15               1       Eco
# 3             1       0              1   60               1       Eco
# 4             1       0              1   70               1       Eco
#
#    Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0              265             0                                  0
# 1             2464             0                                  0
# 2             2138             0                                  0
# 3              623             0                                  0
# 4              354             0                                  0
#
#    Food and drink  ...  Online support  Ease of Online booking  \
# 0               0  ...               2                       3
# ...

# %%
# One Hot Encoding

# %%
data = pd.get_dummies(data, columns=["Class"])

# %%
data.head()
# Out:
#    satisfaction  Gender  Customer Type  Age  Type of Travel  Flight Distance  \
# 0             1       0              1   65               1              265
# 1             1       1              1   47               1             2464
# 2             1       0              1   15               1             2138
# 3             1       0              1   60               1              623
# 4             1       0              1   70               1              354
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Gate location  ...  Leg room service  Baggage handling  Checkin service  \
# ...

# %%
data.drop(["Class_Eco Plus"], axis=1, inplace=True)

# %%
data["Class_Business"] = data["Class_Business"].map({True : 1, False: 0})
data["Class_Eco"] = data["Class_Eco"].map({True : 1, False: 0})

# %%
data.head()
# Out:
#    satisfaction  Gender  Customer Type  Age  Type of Travel  Flight Distance  \
# 0             1       0              1   65               1              265
# 1             1       1              1   47               1             2464
# 2             1       0              1   15               1             2138
# 3             1       0              1   60               1              623
# 4             1       0              1   70               1              354
#
#    Seat comfort  Departure/Arrival time convenient  Food and drink  \
# 0             0                                  0               0
# 1             0                                  0               0
# 2             0                                  0               0
# 3             0                                  0               0
# 4             0                                  0               0
#
#    Gate location  ...  On-board service  Leg room service  Baggage handling  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   satisfaction                       129880 non-null  int64
#  1   Gender                             129880 non-null  int64
#  2   Customer Type                      129880 non-null  int64
#  3   Age                                129880 non-null  int64
#  4   Type of Travel                     129880 non-null  int64
#  5   Flight Distance                    129880 non-null  int64
#  6   Seat comfort                       129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Food and drink                     129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Inflight wifi service              129880 non-null  int64
# ...

# %%
# Logistic Regression Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
y = data["satisfaction"]

# %%
X = data.drop(["satisfaction"], axis=1)

# %%
X.shape, y.shape
# Out:
# ((129880, 23), (129880,))

# %%
# Normalization of Data

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-0.98533997,  0.47342178,  1.69135082, ..., -0.39164371,
#         -0.95806953,  1.10790047],
#        [ 1.01487815,  0.47342178,  0.50081965, ...,  7.54771421,
#          1.04376558, -0.90260816],
#        [-0.98533997,  0.47342178, -1.61568021, ..., -0.39164371,
#         -0.95806953,  1.10790047],
#        ...,
#        [ 1.01487815, -2.11228136,  1.9559133 , ...,  3.85135741,
#         -0.95806953,  1.10790047],
#        [ 1.01487815, -2.11228136,  1.75749144, ...,  4.94464604,
#         -0.95806953,  1.10790047],
#        [-0.98533997, -2.11228136, -0.09444593, ...,  4.45006309,
#         -0.95806953,  1.10790047]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.20, random_state= 42 )

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((103904, 23), (25976, 23), (103904,), (25976,))

# %%
model = LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict = model.predict(X_test)

# %%
y_predict
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %%
y_test
# Out:
#         satisfaction
# 103044             1
# 43282              0
# 65543              1
# 65083              1
# 76496              0
# ...              ...
# 121239             1
# 6010               1
# 101127             1
# 82323              1
# 61871              1
#
# [25976 rows x 1 columns]

# %%
# Evaluation of Model

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test,y_predict)

# %%
print(f"Accuracy: {accuracy: .2f}")
# Out:
# Accuracy:  0.84

# %%
# Confusion Matrix and ROC Curve

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, roc_auc_score

# %%
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()

# %%
y_probs = model.predict_proba(X_test)[:, 1]

fpr, tpr, thresholds = roc_curve(y_test, y_probs) # False Positive Rate, True Positive Rate, thresholds

plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {roc_auc_score(y_test, y_probs):.2f})")
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend()
plt.show()

# %%
# A score of 0.91 is very high, indicating that the model has a strong ability to distinguish between the two classes—91% of the time,
# it ranks a randomly chosen positive instance higher than a randomly chosen negative instance.
